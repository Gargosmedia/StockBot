# %%
'''LIBRARIES'''
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"] = '-1'


from datetime import datetime, date
import yfinance as yf
from keras.models import Sequential 
from keras.layers import Dense, LSTM, Dropout
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
priceScaler, volumeScaler = 0, 0

def ManualNorm(notnormList, pv):
    global priceScaler, volumeScaler
    outputList = notnormList
    maxValue = 0
    
    for i in notnormList:
        maxTmp = max(i)
        if maxTmp > maxValue:
            maxValue = maxTmp
            
    for lidx, l in enumerate(notnormList):
        for jidx, j in enumerate(l):
            outputList[lidx][jidx] = j/maxValue
            
    if pv == 0:
        priceScaler = maxValue
    elif pv == 1:
        volumeScaler = maxValue
    
    return outputList

def ManualDenorm(normList, pv):
    global priceScaler, volumeScaler
    outputList = normList

    if pv == 0:
        maxValue = priceScaler
    elif pv == 1:
        maxValue = volumeScaler
    
    for lidx, l in enumerate(normList):
        for jidx, j in enumerate(l):
            outputList[lidx][jidx] = j*maxValue
            
    return outputList


'''ohlcvValue: Index 0-Open, 1-High, 2-Low, 3-Close, 4-Volume'''
def getDataTarget(valuesListNormalized, numDaysForPrediction, numDaysPredicting, ohlcvValue):
    '''predicting based on numDaysForPrediction, predicting average for next numDaysPredicting'''
    step = numDaysForPrediction+numDaysPredicting
    step = 1
    '''targetWeek can be used for simulating sell later on'''
    targetWeek = []
    
    forPredictionFullLocal = []
    targetFullLocal = []
        
    for idx in range(0,(len(valuesListNormalized)-(numDaysForPrediction)-(numDaysPredicting)),step):
        #print(idx)
        '''making a list of numDaysForPrediction(20) from valuesListNormalized [1,2,3,..., 20] [2,3,4,...,21] ...'''
        forPredictionSingle = valuesListNormalized[idx:idx+numDaysForPrediction]
        forPredictionFullLocal += [forPredictionSingle]

        '''make a list of targets, average of next numDaysPredicting, for 0-20, getting 20-25'''
        targetRow = valuesListNormalized[idx+numDaysForPrediction:idx+numDaysForPrediction+numDaysPredicting]
        targetTotal = 0
        '''saving target week for later'''
        targetWeek+=[targetRow]
        
        for day in targetRow:
            targetTotal += day[ohlcvValue] # Index 0-Open, 1-High, 2-Low, 3-Close, 4-Volume
        targetFullLocal +=  [targetTotal/numDaysPredicting]

    return forPredictionFullLocal, targetFullLocal, targetWeek



def graphPrice(valuesList, valuesListNormalized, ema200):
    plt.plot([el[0:5] for el in valuesListNormalized])
    plt.show()

    plt.plot(ema200, label="200 Min EMA", color="red")
    plt.plot([row[3] for row in valuesList], label="Close Price", color="grey")
    plt.legend(loc='upper left')
    plt.show
    
def GetValuesListNormalized(ticker, period, interval):
    tickerDf = yf.download(tickers=ticker, period=period, interval=interval)
    ### '''getting data from dataframe'''
    dateIndexFrame=tickerDf.index

    '''turning all values to list'''
    valuesList = tickerDf.values.tolist()

    '''getting close values for EMA 200'''
    closeList = tickerDf["Close"]
    ema200 = closeList.ewm(span=200).mean().tolist()

    '''getting only prices (first 4 elements) / volumes (5th) for normaliztion'''
    priceList=[]
    for idx, el in enumerate(valuesList):
        x = el[0:4]
        x.append(ema200[idx])     #Adding EMA200
        priceList+=[x]

    volumeList = [[row[5]] for row in valuesList]
        
    '''normalizing with ^ functions'''
    priceListNormalized = ManualNorm(priceList,0) 
    
    volumeListNormalized = ManualNorm(volumeList,1)    

    '''recollecting prices/volume in one list '''
    valuesListNormalized = []

    '''valuesListNormalized - dataframe normalized'''
    for idx, pricesRow in enumerate(priceListNormalized):
        valuesRow = pricesRow
        valuesRow.append(volumeListNormalized[idx][0])
        valuesListNormalized+=[valuesRow]

    return valuesListNormalized

def PrepareTicker(ticker, period, interval):
    
    valuesListNormalized = GetValuesListNormalized(ticker, period, interval)
    
    '''to numpy array and splitting to train and test datasets, x_train - y_train, x_test - y_test'''
    forPredictionFull, targetFull, targetWeek = getDataTarget(valuesListNormalized, 20, 5, 3);

    data = np.array(forPredictionFull, dtype=float)
    target = np.array(targetFull,dtype=float)
    
    print (data.shape)
    print (target.shape)

    #graphPrice(valuesList, valuesListNormalized, ema200)
    
    return data, target, targetWeek, priceScaler, volumeScaler

# %%
def PrepareModel():
    '''Setup model'''
    model=Sequential()
    '''layers'''
    model.add(LSTM((128), batch_input_shape=(None, None, 6),return_sequences=True))

    model.add(LSTM((64), batch_input_shape=(None, None, 6),return_sequences=True))

    model.add(LSTM((64), batch_input_shape=(None, None, 6),return_sequences=True))

    model.add(LSTM((32), batch_input_shape=(None, None, 6),return_sequences=True))

    model.add(LSTM((6), batch_input_shape=(None, None, 6)))

    model.add(Dense(1))

    model.compile(loss='mean_absolute_error', optimizer='adam',metrics=['accuracy'])
    
    return model

# %%
def modelTest(history, x_test, y_test):
    global model 
    '''testing / predicitng'''
    predictionNormalized = model.predict(x_test)
    
    '''manual prediction inverse'''
    predictionInversed = ManualDenorm(predictionNormalized,0)

    '''manual target inverse'''
    targetInversed = ManualDenorm([[el] for el in y_test],0)

    '''prediciton / target scatter'''
    plt.scatter(range(len(predictionInversed)), predictionInversed , c='r')
    plt.scatter(range(len(targetInversed)), targetInversed, c='g')
    plt.show()

    '''loss graph'''
    plt.plot(history.history['loss'])
    plt.show()
    
    return predictionInversed, targetInversed



def tradeSimulation(predOnWeek, targetWeek, predictionInversed, targetInversed, verbose):
    
    '''getting close list to simulate buying on close the day before prediction week'''
    x_testPrices = [row[-1][0:4] for row in predOnWeek] #get last day before prediciton week, and strip volume from list
    #x_testInversed = priceScaler.inverse_transform(x_testPrices) #inverse normalization
    x_testInversed = ManualDenorm(x_testPrices,0) #inverse normalization
    x_testOnlyClose = [round(row[3],2) for row in x_testInversed] #get Close price of the day

    tooHighNum = 0
    tooLowNum = 0
    goodGuessNum = 0
    balanceTotal = 0
    balancePercTotal = 0
    
    realBalanceTotal = 0
    realBalancePercTotal = 0
    
    numTrades=0
    passiveTotal = 0
    
    for idx in range(len(x_testOnlyClose)):

        lastWeekClose = x_testOnlyClose[idx]
        weekPredictionAvg = round(predictionInversed[idx][0],2)
        weekActualAvg = round(targetInversed[idx][0],2)

        if weekPredictionAvg < weekActualAvg*0.99: tooLowNum+=1
        elif weekPredictionAvg > weekActualAvg*1.01: tooHighNum+=1
        else: goodGuessNum+=1
    
        '''calculating balance without ai interference'''   
        tradeTotal = round(weekActualAvg - lastWeekClose,2)
    
        targetWeekPrices = [day[0:4]for day in targetWeek[idx]]
        targetWeekPricesInversed = ManualDenorm(targetWeekPrices,0)
        closeWeekPrice = targetWeekPricesInversed[-1][3]
        passiveTotal+= round(closeWeekPrice - lastWeekClose,2)
        
        if verbose:
            print("\n\nLast Week Closed at ", lastWeekClose, "\t Week Closing at ",round(closeWeekPrice,2),"\t Passive Trade: ", round(passiveTotal,2))
        
        '''only buying those bot liked'''
        if lastWeekClose < weekPredictionAvg: #if next week looks good, we buy a stock and sell on predicted price (tradeTotal)
            '''selling on next week average price (we don't know it)'''
            numTrades+=1

            tradePercTotal = round((tradeTotal/lastWeekClose*100),2)
            balanceTotal+=tradeTotal
            balancePercTotal+=tradePercTotal

            if verbose:
                print("Avg Prediction: ", weekPredictionAvg, "    \tAvg Actual: ", weekActualAvg, "\tTrade Total: ", tradeTotal,"$\t", tradePercTotal,"%")

            
            '''selling on predicted price if reached, if not selling on week close'''
            
            gotPredicted=False;

            for num, day in enumerate(targetWeekPricesInversed):  
                maxDayPrice = day[1]
                if verbose:
                    print("Day", num+1,"Price: ",round(maxDayPrice,2))
                    
                if maxDayPrice > weekPredictionAvg:
                    if verbose:
                        print("Prediction reached. Selling at: ", weekPredictionAvg)
                    realTradeTotal = round(weekPredictionAvg - lastWeekClose,2)
                    gotPredicted=True
                    break;
            if not gotPredicted:
                closeWeekPrice = targetWeekPricesInversed[-1][3]
                if verbose:
                    print("Prediction not reached. Selling at: ", closeWeekPrice)
                realTradeTotal = round(closeWeekPrice - lastWeekClose,2)
         
            realTradePercTotal = round((realTradeTotal/lastWeekClose*100),2)
            realBalanceTotal+=realTradeTotal
            realBalancePercTotal+=realTradePercTotal
            if verbose:
                print("Real Trade Total: ", realTradeTotal,"$\t", realTradePercTotal,"%")


    if (numTrades==0):
        numTrades=-1

    print("\nTrades Made: ", numTrades)
    print("\nPassive Balance Total: \t", round(passiveTotal,2),"$")
    print("AI Balance Total: \t", round(balanceTotal,2), "$  \tAvg Trade Perc Change: ",round(balancePercTotal/numTrades,2),"%" )
    print("Real AI Balance Total: \t", round(realBalanceTotal,2), "$  \tAvg Trade Perc Change: ",round(realBalancePercTotal/numTrades,2),"%" )

    print("\ntooHighNum: ", tooHighNum, "\ntooLowNum: ",tooLowNum,"\ngoodGuessNum: ",goodGuessNum)

# %%
def Train(epochsNum, x_train, y_train, x_test, y_test):
    global model
    history = model.fit(x_train, y_train, verbose=2, epochs=epochsNum, validation_data=(x_test, y_test))
    return history
    
    
def TrainModel(epochsNum, data, target, targetWeek, randState=1, testSize=0.2):
    global model
    
    
    x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=testSize, random_state=randState)
    xTrainSim, xTestSim, yTrainSim, yTestSim = train_test_split(targetWeek, target, test_size=testSize, random_state=randState)

    history = Train(epochsNum, x_train, y_train, x_test, y_test)
    
    return history, x_test, y_test, xTestSim
      
        
def TestModel(history, x_test, y_test, xTestSim, verbose=False):
    
    predictionInversed, targetInversed = modelTest(history, x_test, y_test)
    tradeSimulation(x_test, xTestSim, predictionInversed, targetInversed, verbose)

# %%
#model = PrepareModel()

def Main():
    global model
    tickers="SPY"
    epochs=1000
    period="120d"
    interval="1h"
    
    data, target, targetWeek, priceScaler, volumeScaler = PrepareTicker(tickers, period, interval)
   
    history, x_test, y_test, xTestSim = TrainModel(epochs, data, target, targetWeek)
    TestModel(history, x_test, y_test, xTestSim, verbose=True)
    
    model.save('Models/'+tickers+"_"+str(epochs)+"ep_"+period+"_"+interval+"_EWA")

Main()


def PredNextWeek():
    ticker = "SPY"
    period = "20h"
    interval = "1h"
    
    
    valuesListNormalized = GetValuesListNormalized(ticker, period,interval)

PredNextWeek()   

          
def LoadModel():
    global model
    model = keras.models.load_model('Models/SPY')
# Out:
# [*********************100%***********************]  1 of 1 completed
# (815, 20, 6)
# (815,)
# Epoch 1/1000
# 21/21 - 4s - loss: 0.1884 - accuracy: 0.0000e+00 - val_loss: 0.0680 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 21/21 - 2s - loss: 0.0534 - accuracy: 0.0000e+00 - val_loss: 0.0528 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 21/21 - 2s - loss: 0.0415 - accuracy: 0.0000e+00 - val_loss: 0.0443 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 21/21 - 2s - loss: 0.0304 - accuracy: 0.0000e+00 - val_loss: 0.0253 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 21/21 - 2s - loss: 0.0297 - accuracy: 0.0000e+00 - val_loss: 0.0352 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 21/21 - 2s - loss: 0.0262 - accuracy: 0.0000e+00 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 21/21 - 2s - loss: 0.0208 - accuracy: 0.0000e+00 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 21/21 - 2s - loss: 0.0272 - accuracy: 0.0000e+00 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 21/21 - 2s - loss: 0.0221 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# 21/21 - 2s - loss: 0.0233 - accuracy: 0.0000e+00 - val_loss: 0.0355 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# 21/21 - 2s - loss: 0.0275 - accuracy: 0.0000e+00 - val_loss: 0.0198 - val_accuracy: 0.0000e+00
# Epoch 12/1000
# 21/21 - 2s - loss: 0.0196 - accuracy: 0.0000e+00 - val_loss: 0.0185 - val_accuracy: 0.0000e+00
# Epoch 13/1000
# 21/21 - 2s - loss: 0.0209 - accuracy: 0.0000e+00 - val_loss: 0.0293 - val_accuracy: 0.0000e+00
# Epoch 14/1000
# 21/21 - 2s - loss: 0.0226 - accuracy: 0.0000e+00 - val_loss: 0.0376 - val_accuracy: 0.0000e+00
# Epoch 15/1000
# 21/21 - 2s - loss: 0.0361 - accuracy: 0.0000e+00 - val_loss: 0.0222 - val_accuracy: 0.0000e+00
# Epoch 16/1000
# 21/21 - 2s - loss: 0.0266 - accuracy: 0.0000e+00 - val_loss: 0.0204 - val_accuracy: 0.0000e+00
# Epoch 17/1000
# 21/21 - 2s - loss: 0.0218 - accuracy: 0.0000e+00 - val_loss: 0.0233 - val_accuracy: 0.0000e+00
# Epoch 18/1000
# 21/21 - 2s - loss: 0.0213 - accuracy: 0.0000e+00 - val_loss: 0.0187 - val_accuracy: 0.0000e+00
# Epoch 19/1000
# 21/21 - 2s - loss: 0.0194 - accuracy: 0.0000e+00 - val_loss: 0.0181 - val_accuracy: 0.0000e+00
# Epoch 20/1000
# 21/21 - 2s - loss: 0.0229 - accuracy: 0.0000e+00 - val_loss: 0.0288 - val_accuracy: 0.0000e+00
# Epoch 21/1000
# 21/21 - 2s - loss: 0.0224 - accuracy: 0.0000e+00 - val_loss: 0.0193 - val_accuracy: 0.0000e+00
# Epoch 22/1000
# 21/21 - 2s - loss: 0.0187 - accuracy: 0.0000e+00 - val_loss: 0.0203 - val_accuracy: 0.0000e+00
# Epoch 23/1000
# 21/21 - 2s - loss: 0.0196 - accuracy: 0.0000e+00 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# 21/21 - 2s - loss: 0.0194 - accuracy: 0.0000e+00 - val_loss: 0.0305 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# 21/21 - 2s - loss: 0.0246 - accuracy: 0.0000e+00 - val_loss: 0.0339 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# 21/21 - 2s - loss: 0.0256 - accuracy: 0.0000e+00 - val_loss: 0.0223 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# 21/21 - 2s - loss: 0.0202 - accuracy: 0.0000e+00 - val_loss: 0.0223 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# 21/21 - 2s - loss: 0.0198 - accuracy: 0.0000e+00 - val_loss: 0.0178 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# 21/21 - 2s - loss: 0.0254 - accuracy: 0.0000e+00 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# 21/21 - 2s - loss: 0.0199 - accuracy: 0.0000e+00 - val_loss: 0.0174 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# 21/21 - 2s - loss: 0.0191 - accuracy: 0.0000e+00 - val_loss: 0.0185 - val_accuracy: 0.0000e+00
# Epoch 32/1000
# 21/21 - 2s - loss: 0.0196 - accuracy: 0.0000e+00 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# Epoch 33/1000
# 21/21 - 2s - loss: 0.0180 - accuracy: 0.0000e+00 - val_loss: 0.0192 - val_accuracy: 0.0000e+00
# Epoch 34/1000
# 21/21 - 2s - loss: 0.0183 - accuracy: 0.0000e+00 - val_loss: 0.0160 - val_accuracy: 0.0000e+00
# Epoch 35/1000
# 21/21 - 2s - loss: 0.0196 - accuracy: 0.0000e+00 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 36/1000
# 21/21 - 2s - loss: 0.0211 - accuracy: 0.0000e+00 - val_loss: 0.0304 - val_accuracy: 0.0000e+00
# Epoch 37/1000
# 21/21 - 2s - loss: 0.0191 - accuracy: 0.0000e+00 - val_loss: 0.0273 - val_accuracy: 0.0000e+00
# Epoch 38/1000
# 21/21 - 2s - loss: 0.0208 - accuracy: 0.0000e+00 - val_loss: 0.0168 - val_accuracy: 0.0000e+00
# Epoch 39/1000
# 21/21 - 2s - loss: 0.0186 - accuracy: 0.0000e+00 - val_loss: 0.0355 - val_accuracy: 0.0000e+00
# Epoch 40/1000
# 21/21 - 2s - loss: 0.0250 - accuracy: 0.0000e+00 - val_loss: 0.0168 - val_accuracy: 0.0000e+00
# Epoch 41/1000
# 21/21 - 2s - loss: 0.0208 - accuracy: 0.0000e+00 - val_loss: 0.0436 - val_accuracy: 0.0000e+00
# Epoch 42/1000
# 21/21 - 2s - loss: 0.0297 - accuracy: 0.0000e+00 - val_loss: 0.0188 - val_accuracy: 0.0000e+00
# Epoch 43/1000
# 21/21 - 2s - loss: 0.0189 - accuracy: 0.0000e+00 - val_loss: 0.0187 - val_accuracy: 0.0000e+00
# Epoch 44/1000
# 21/21 - 2s - loss: 0.0172 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 45/1000
# 21/21 - 2s - loss: 0.0194 - accuracy: 0.0000e+00 - val_loss: 0.0170 - val_accuracy: 0.0000e+00
# Epoch 46/1000
# 21/21 - 2s - loss: 0.0193 - accuracy: 0.0000e+00 - val_loss: 0.0310 - val_accuracy: 0.0000e+00
# Epoch 47/1000
# 21/21 - 2s - loss: 0.0198 - accuracy: 0.0000e+00 - val_loss: 0.0197 - val_accuracy: 0.0000e+00
# Epoch 48/1000
# 21/21 - 2s - loss: 0.0176 - accuracy: 0.0000e+00 - val_loss: 0.0177 - val_accuracy: 0.0000e+00
# Epoch 49/1000
# 21/21 - 2s - loss: 0.0197 - accuracy: 0.0000e+00 - val_loss: 0.0180 - val_accuracy: 0.0000e+00
# Epoch 50/1000
# 21/21 - 2s - loss: 0.0201 - accuracy: 0.0000e+00 - val_loss: 0.0367 - val_accuracy: 0.0000e+00
# Epoch 51/1000
# 21/21 - 2s - loss: 0.0219 - accuracy: 0.0000e+00 - val_loss: 0.0165 - val_accuracy: 0.0000e+00
# Epoch 52/1000
# 21/21 - 2s - loss: 0.0203 - accuracy: 0.0000e+00 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# Epoch 53/1000
# 21/21 - 2s - loss: 0.0229 - accuracy: 0.0000e+00 - val_loss: 0.0278 - val_accuracy: 0.0000e+00
# Epoch 54/1000
# 21/21 - 2s - loss: 0.0205 - accuracy: 0.0000e+00 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 55/1000
# 21/21 - 2s - loss: 0.0173 - accuracy: 0.0000e+00 - val_loss: 0.0152 - val_accuracy: 0.0000e+00
# Epoch 56/1000
# 21/21 - 2s - loss: 0.0193 - accuracy: 0.0000e+00 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 57/1000
# 21/21 - 2s - loss: 0.0196 - accuracy: 0.0000e+00 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 58/1000
# 21/21 - 2s - loss: 0.0175 - accuracy: 0.0000e+00 - val_loss: 0.0169 - val_accuracy: 0.0000e+00
# Epoch 59/1000
# 21/21 - 2s - loss: 0.0180 - accuracy: 0.0000e+00 - val_loss: 0.0158 - val_accuracy: 0.0000e+00
# Epoch 60/1000
# 21/21 - 2s - loss: 0.0238 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 61/1000
# 21/21 - 2s - loss: 0.0212 - accuracy: 0.0000e+00 - val_loss: 0.0164 - val_accuracy: 0.0000e+00
# Epoch 62/1000
# 21/21 - 2s - loss: 0.0171 - accuracy: 0.0000e+00 - val_loss: 0.0203 - val_accuracy: 0.0000e+00
# Epoch 63/1000
# 21/21 - 2s - loss: 0.0189 - accuracy: 0.0000e+00 - val_loss: 0.0160 - val_accuracy: 0.0000e+00
# Epoch 64/1000
# 21/21 - 2s - loss: 0.0158 - accuracy: 0.0000e+00 - val_loss: 0.0163 - val_accuracy: 0.0000e+00
# Epoch 65/1000
# 21/21 - 2s - loss: 0.0170 - accuracy: 0.0000e+00 - val_loss: 0.0336 - val_accuracy: 0.0000e+00
# Epoch 66/1000
# 21/21 - 2s - loss: 0.0239 - accuracy: 0.0000e+00 - val_loss: 0.0186 - val_accuracy: 0.0000e+00
# Epoch 67/1000
# 21/21 - 2s - loss: 0.0177 - accuracy: 0.0000e+00 - val_loss: 0.0222 - val_accuracy: 0.0000e+00
# Epoch 68/1000
# 21/21 - 2s - loss: 0.0159 - accuracy: 0.0000e+00 - val_loss: 0.0167 - val_accuracy: 0.0000e+00
# Epoch 69/1000
# 21/21 - 2s - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.0349 - val_accuracy: 0.0000e+00
# Epoch 70/1000
# 21/21 - 2s - loss: 0.0216 - accuracy: 0.0000e+00 - val_loss: 0.0150 - val_accuracy: 0.0000e+00
# Epoch 71/1000
# 21/21 - 2s - loss: 0.0176 - accuracy: 0.0000e+00 - val_loss: 0.0158 - val_accuracy: 0.0000e+00
# Epoch 72/1000
# 21/21 - 2s - loss: 0.0235 - accuracy: 0.0000e+00 - val_loss: 0.0179 - val_accuracy: 0.0000e+00
# Epoch 73/1000
# 21/21 - 2s - loss: 0.0168 - accuracy: 0.0000e+00 - val_loss: 0.0145 - val_accuracy: 0.0000e+00
# Epoch 74/1000
# 21/21 - 2s - loss: 0.0160 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 75/1000
# 21/21 - 2s - loss: 0.0178 - accuracy: 0.0000e+00 - val_loss: 0.0159 - val_accuracy: 0.0000e+00
# Epoch 76/1000
# 21/21 - 2s - loss: 0.0158 - accuracy: 0.0000e+00 - val_loss: 0.0188 - val_accuracy: 0.0000e+00
# Epoch 77/1000
# 21/21 - 2s - loss: 0.0166 - accuracy: 0.0000e+00 - val_loss: 0.0138 - val_accuracy: 0.0000e+00
# Epoch 78/1000
# 21/21 - 2s - loss: 0.0205 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 79/1000
# 21/21 - 2s - loss: 0.0172 - accuracy: 0.0000e+00 - val_loss: 0.0178 - val_accuracy: 0.0000e+00
# Epoch 80/1000
# 21/21 - 2s - loss: 0.0158 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 81/1000
# 21/21 - 2s - loss: 0.0171 - accuracy: 0.0000e+00 - val_loss: 0.0140 - val_accuracy: 0.0000e+00
# Epoch 82/1000
# 21/21 - 2s - loss: 0.0148 - accuracy: 0.0000e+00 - val_loss: 0.0151 - val_accuracy: 0.0000e+00
# Epoch 83/1000
# 21/21 - 2s - loss: 0.0152 - accuracy: 0.0000e+00 - val_loss: 0.0168 - val_accuracy: 0.0000e+00
# Epoch 84/1000
# 21/21 - 2s - loss: 0.0210 - accuracy: 0.0000e+00 - val_loss: 0.0192 - val_accuracy: 0.0000e+00
# Epoch 85/1000
# 21/21 - 2s - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 86/1000
# 21/21 - 2s - loss: 0.0159 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 87/1000
# 21/21 - 2s - loss: 0.0153 - accuracy: 0.0000e+00 - val_loss: 0.0268 - val_accuracy: 0.0000e+00
# Epoch 88/1000
# 21/21 - 2s - loss: 0.0171 - accuracy: 0.0000e+00 - val_loss: 0.0273 - val_accuracy: 0.0000e+00
# Epoch 89/1000
# 21/21 - 2s - loss: 0.0201 - accuracy: 0.0000e+00 - val_loss: 0.0160 - val_accuracy: 0.0000e+00
# Epoch 90/1000
# 21/21 - 2s - loss: 0.0151 - accuracy: 0.0000e+00 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 91/1000
# 21/21 - 2s - loss: 0.0202 - accuracy: 0.0000e+00 - val_loss: 0.0194 - val_accuracy: 0.0000e+00
# Epoch 92/1000
# 21/21 - 2s - loss: 0.0193 - accuracy: 0.0000e+00 - val_loss: 0.0236 - val_accuracy: 0.0000e+00
# Epoch 93/1000
# 21/21 - 2s - loss: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0184 - val_accuracy: 0.0000e+00
# Epoch 94/1000
# 21/21 - 2s - loss: 0.0162 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 95/1000
# 21/21 - 2s - loss: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0169 - val_accuracy: 0.0000e+00
# Epoch 96/1000
# 21/21 - 2s - loss: 0.0163 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 97/1000
# 21/21 - 2s - loss: 0.0164 - accuracy: 0.0000e+00 - val_loss: 0.0128 - val_accuracy: 0.0000e+00
# Epoch 98/1000
# 21/21 - 2s - loss: 0.0181 - accuracy: 0.0000e+00 - val_loss: 0.0204 - val_accuracy: 0.0000e+00
# Epoch 99/1000
# 21/21 - 2s - loss: 0.0191 - accuracy: 0.0000e+00 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 100/1000
# 21/21 - 2s - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 101/1000
# 21/21 - 2s - loss: 0.0142 - accuracy: 0.0000e+00 - val_loss: 0.0169 - val_accuracy: 0.0000e+00
# Epoch 102/1000
# 21/21 - 2s - loss: 0.0167 - accuracy: 0.0000e+00 - val_loss: 0.0183 - val_accuracy: 0.0000e+00
# Epoch 103/1000
# 21/21 - 2s - loss: 0.0168 - accuracy: 0.0000e+00 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 104/1000
# 21/21 - 2s - loss: 0.0140 - accuracy: 0.0000e+00 - val_loss: 0.0140 - val_accuracy: 0.0000e+00
# Epoch 105/1000
# 21/21 - 2s - loss: 0.0156 - accuracy: 0.0000e+00 - val_loss: 0.0299 - val_accuracy: 0.0000e+00
# Epoch 106/1000
# 21/21 - 2s - loss: 0.0220 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 107/1000
# 21/21 - 2s - loss: 0.0177 - accuracy: 0.0000e+00 - val_loss: 0.0195 - val_accuracy: 0.0000e+00
# Epoch 108/1000
# 21/21 - 2s - loss: 0.0179 - accuracy: 0.0000e+00 - val_loss: 0.0183 - val_accuracy: 0.0000e+00
# Epoch 109/1000
# 21/21 - 2s - loss: 0.0197 - accuracy: 0.0000e+00 - val_loss: 0.0169 - val_accuracy: 0.0000e+00
# Epoch 110/1000
# 21/21 - 2s - loss: 0.0181 - accuracy: 0.0000e+00 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 111/1000
# 21/21 - 2s - loss: 0.0162 - accuracy: 0.0000e+00 - val_loss: 0.0168 - val_accuracy: 0.0000e+00
# Epoch 112/1000
# 21/21 - 2s - loss: 0.0170 - accuracy: 0.0000e+00 - val_loss: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 113/1000
# 21/21 - 2s - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 114/1000
# 21/21 - 2s - loss: 0.0131 - accuracy: 0.0000e+00 - val_loss: 0.0134 - val_accuracy: 0.0000e+00
# Epoch 115/1000
# 21/21 - 2s - loss: 0.0158 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 116/1000
# 21/21 - 2s - loss: 0.0127 - accuracy: 0.0000e+00 - val_loss: 0.0173 - val_accuracy: 0.0000e+00
# Epoch 117/1000
# 21/21 - 2s - loss: 0.0160 - accuracy: 0.0000e+00 - val_loss: 0.0128 - val_accuracy: 0.0000e+00
# Epoch 118/1000
# 21/21 - 2s - loss: 0.0142 - accuracy: 0.0000e+00 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 119/1000
# 21/21 - 2s - loss: 0.0130 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 120/1000
# 21/21 - 2s - loss: 0.0140 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 121/1000
# 21/21 - 2s - loss: 0.0151 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 0.0000e+00
# Epoch 122/1000
# 21/21 - 2s - loss: 0.0154 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 123/1000
# 21/21 - 2s - loss: 0.0143 - accuracy: 0.0000e+00 - val_loss: 0.0161 - val_accuracy: 0.0000e+00
# Epoch 124/1000
# 21/21 - 2s - loss: 0.0156 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 125/1000
# 21/21 - 2s - loss: 0.0139 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 126/1000
# 21/21 - 2s - loss: 0.0134 - accuracy: 0.0000e+00 - val_loss: 0.0136 - val_accuracy: 0.0000e+00
# Epoch 127/1000
# 21/21 - 2s - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 128/1000
# 21/21 - 2s - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 129/1000
# 21/21 - 2s - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 130/1000
# 21/21 - 2s - loss: 0.0157 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 131/1000
# 21/21 - 2s - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0157 - val_accuracy: 0.0000e+00
# Epoch 132/1000
# 21/21 - 2s - loss: 0.0154 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 133/1000
# 21/21 - 2s - loss: 0.0139 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 134/1000
# 21/21 - 2s - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 135/1000
# 21/21 - 2s - loss: 0.0191 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 136/1000
# 21/21 - 2s - loss: 0.0130 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 137/1000
# 21/21 - 2s - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0194 - val_accuracy: 0.0000e+00
# Epoch 138/1000
# 21/21 - 2s - loss: 0.0148 - accuracy: 0.0000e+00 - val_loss: 0.0140 - val_accuracy: 0.0000e+00
# Epoch 139/1000
# 21/21 - 2s - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 140/1000
# 21/21 - 2s - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 141/1000
# 21/21 - 2s - loss: 0.0194 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 142/1000
# 21/21 - 2s - loss: 0.0149 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 143/1000
# 21/21 - 2s - loss: 0.0124 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 144/1000
# 21/21 - 2s - loss: 0.0133 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 145/1000
# 21/21 - 2s - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 146/1000
# 21/21 - 2s - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0180 - val_accuracy: 0.0000e+00
# Epoch 147/1000
# 21/21 - 2s - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 148/1000
# 21/21 - 2s - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 0.0000e+00
# Epoch 149/1000
# 21/21 - 2s - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 150/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 151/1000
# 21/21 - 2s - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 152/1000
# 21/21 - 2s - loss: 0.0171 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 153/1000
# 21/21 - 2s - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 154/1000
# 21/21 - 2s - loss: 0.0125 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 155/1000
# 21/21 - 2s - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 156/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 157/1000
# 21/21 - 2s - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 158/1000
# 21/21 - 2s - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 159/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0099 - val_accuracy: 0.0000e+00
# Epoch 160/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 161/1000
# 21/21 - 2s - loss: 0.0130 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 162/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0091 - val_accuracy: 0.0000e+00
# Epoch 163/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 164/1000
# 21/21 - 2s - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 165/1000
# 21/21 - 2s - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 166/1000
# 21/21 - 2s - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0148 - val_accuracy: 0.0000e+00
# Epoch 167/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0094 - val_accuracy: 0.0000e+00
# Epoch 168/1000
# 21/21 - 2s - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.0159 - val_accuracy: 0.0000e+00
# Epoch 169/1000
# 21/21 - 2s - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 0.0000e+00
# Epoch 170/1000
# 21/21 - 2s - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 171/1000
# 21/21 - 2s - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0131 - val_accuracy: 0.0000e+00
# Epoch 172/1000
# 21/21 - 2s - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 173/1000
# 21/21 - 2s - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 174/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 175/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0187 - val_accuracy: 0.0000e+00
# Epoch 176/1000
# 21/21 - 2s - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 177/1000
# 21/21 - 2s - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 178/1000
# 21/21 - 2s - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0178 - val_accuracy: 0.0000e+00
# Epoch 179/1000
# 21/21 - 2s - loss: 0.0127 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 180/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 181/1000
# 21/21 - 2s - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 182/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 183/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 184/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 185/1000
# 21/21 - 2s - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 186/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 187/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 188/1000
# 21/21 - 2s - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 189/1000
# 21/21 - 2s - loss: 0.0123 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 190/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 191/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 192/1000
# 21/21 - 2s - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 193/1000
# 21/21 - 2s - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 194/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0146 - val_accuracy: 0.0000e+00
# Epoch 195/1000
# 21/21 - 2s - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 196/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 197/1000
# 21/21 - 2s - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 198/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0265 - val_accuracy: 0.0000e+00
# Epoch 199/1000
# 21/21 - 2s - loss: 0.0211 - accuracy: 0.0000e+00 - val_loss: 0.0163 - val_accuracy: 0.0000e+00
# Epoch 200/1000
# 21/21 - 2s - loss: 0.0146 - accuracy: 0.0000e+00 - val_loss: 0.0158 - val_accuracy: 0.0000e+00
# Epoch 201/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 202/1000
# 21/21 - 2s - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 203/1000
# 21/21 - 2s - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 204/1000
# 21/21 - 2s - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 205/1000
# 21/21 - 2s - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 206/1000
# 21/21 - 2s - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 207/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 208/1000
# 21/21 - 2s - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 209/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 210/1000
# 21/21 - 2s - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 211/1000
# 21/21 - 2s - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 212/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 213/1000
# 21/21 - 2s - loss: 0.0130 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 214/1000
# 21/21 - 2s - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 215/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 216/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 217/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 218/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 219/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 220/1000
# 21/21 - 2s - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 221/1000
# 21/21 - 2s - loss: 0.0138 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 222/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 223/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 224/1000
# 21/21 - 2s - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 225/1000
# 21/21 - 2s - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0133 - val_accuracy: 0.0000e+00
# Epoch 226/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 227/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 228/1000
# 21/21 - 2s - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 229/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 230/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0134 - val_accuracy: 0.0000e+00
# Epoch 231/1000
# 21/21 - 2s - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0092 - val_accuracy: 0.0000e+00
# Epoch 232/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 233/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 234/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 0.0000e+00
# Epoch 235/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 236/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 237/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 238/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0095 - val_accuracy: 0.0000e+00
# Epoch 239/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 240/1000
# 21/21 - 2s - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0200 - val_accuracy: 0.0000e+00
# Epoch 241/1000
# 21/21 - 2s - loss: 0.0147 - accuracy: 0.0000e+00 - val_loss: 0.0146 - val_accuracy: 0.0000e+00
# Epoch 242/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 243/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 244/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 245/1000
# 21/21 - 2s - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 246/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 247/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 248/1000
# 21/21 - 2s - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 249/1000
# 21/21 - 2s - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 250/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 251/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 252/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 253/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 254/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 255/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 256/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 257/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 258/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 259/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 260/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0140 - val_accuracy: 0.0000e+00
# Epoch 261/1000
# 21/21 - 2s - loss: 0.0137 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 262/1000
# 21/21 - 2s - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 263/1000
# 21/21 - 2s - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 264/1000
# 21/21 - 2s - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 265/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 266/1000
# 21/21 - 2s - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 267/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 268/1000
# 21/21 - 2s - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 269/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 270/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 271/1000
# 21/21 - 2s - loss: 0.0123 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 272/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 273/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 274/1000
# 21/21 - 2s - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 275/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 276/1000
# 21/21 - 2s - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0287 - val_accuracy: 0.0000e+00
# Epoch 277/1000
# 21/21 - 2s - loss: 0.0217 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 278/1000
# 21/21 - 2s - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 279/1000
# 21/21 - 2s - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0129 - val_accuracy: 0.0000e+00
# Epoch 280/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 281/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 282/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 283/1000
# 21/21 - 2s - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 284/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 285/1000
# 21/21 - 2s - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 286/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 287/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 288/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0091 - val_accuracy: 0.0000e+00
# Epoch 289/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 290/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 291/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 292/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 293/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 294/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 295/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 296/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 297/1000
# 21/21 - 2s - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0152 - val_accuracy: 0.0000e+00
# Epoch 298/1000
# 21/21 - 2s - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 299/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 300/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 301/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 302/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 303/1000
# 21/21 - 2s - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 304/1000
# 21/21 - 2s - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 305/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 306/1000
# 21/21 - 2s - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 307/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 308/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 309/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 0.0000e+00
# Epoch 310/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 311/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 312/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 313/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0095 - val_accuracy: 0.0000e+00
# Epoch 314/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 315/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 316/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 317/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 318/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 319/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 320/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0092 - val_accuracy: 0.0000e+00
# Epoch 321/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 322/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0129 - val_accuracy: 0.0000e+00
# Epoch 323/1000
# 21/21 - 2s - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 324/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0134 - val_accuracy: 0.0000e+00
# Epoch 325/1000
# 21/21 - 2s - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0095 - val_accuracy: 0.0000e+00
# Epoch 326/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 327/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 328/1000
# 21/21 - 2s - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 329/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 330/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 331/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 332/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 333/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 334/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 335/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 336/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 337/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 338/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 339/1000
# 21/21 - 2s - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0173 - val_accuracy: 0.0000e+00
# Epoch 340/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 341/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 342/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 343/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 344/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 345/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 346/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 347/1000
# 21/21 - 2s - loss: 0.0124 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 348/1000
# 21/21 - 2s - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0151 - val_accuracy: 0.0000e+00
# Epoch 349/1000
# 21/21 - 2s - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 0.0000e+00
# Epoch 350/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0145 - val_accuracy: 0.0000e+00
# Epoch 351/1000
# 21/21 - 2s - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 352/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 353/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 354/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 355/1000
# 21/21 - 2s - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 356/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 357/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 358/1000
# 21/21 - 2s - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 359/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 360/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 361/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 362/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 363/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 364/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 365/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 366/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 367/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 368/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 369/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 370/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 371/1000
# 21/21 - 2s - loss: 0.0147 - accuracy: 0.0000e+00 - val_loss: 0.0177 - val_accuracy: 0.0000e+00
# Epoch 372/1000
# 21/21 - 2s - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 373/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 374/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 375/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 376/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 377/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 378/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 379/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 380/1000
# 21/21 - 2s - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 381/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 382/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0128 - val_accuracy: 0.0000e+00
# Epoch 383/1000
# 21/21 - 2s - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 384/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 385/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 386/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 387/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 388/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 389/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 390/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 391/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 392/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 393/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 394/1000
# 21/21 - 2s - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 395/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 396/1000
# 21/21 - 2s - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 397/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 398/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 399/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 400/1000
# 21/21 - 2s - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 401/1000
# 21/21 - 2s - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 402/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 403/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 404/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 405/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 406/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 407/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 408/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 409/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 410/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 411/1000
# 21/21 - 2s - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 412/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 413/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 414/1000
# 21/21 - 2s - loss: 0.0124 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 415/1000
# 21/21 - 2s - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 416/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 0.0000e+00
# Epoch 417/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 418/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 419/1000
# 21/21 - 2s - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 420/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 421/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 422/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 423/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 424/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0128 - val_accuracy: 0.0000e+00
# Epoch 425/1000
# 21/21 - 2s - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 426/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 427/1000
# 21/21 - 2s - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 428/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 429/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 430/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 431/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 432/1000
# 21/21 - 2s - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 433/1000
# 21/21 - 2s - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 434/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 435/1000
# 21/21 - 2s - loss: 0.0125 - accuracy: 0.0000e+00 - val_loss: 0.0140 - val_accuracy: 0.0000e+00
# Epoch 436/1000
# 21/21 - 2s - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 437/1000
# ...
# Epoch 465/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 466/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 467/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 468/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 469/1000
# 21/21 - 2s - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 470/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 471/1000
# 21/21 - 2s - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0133 - val_accuracy: 0.0000e+00
# Epoch 472/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 473/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 474/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 475/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 476/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 477/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 478/1000
# 21/21 - 2s - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 479/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 480/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 481/1000
# 21/21 - 2s - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 482/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 483/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 484/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 485/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 486/1000
# 21/21 - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0000e+00
# Epoch 487/1000
# 21/21 - 2s - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 488/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 489/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 490/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 491/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 492/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 493/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 494/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 495/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 496/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 497/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 498/1000
# 21/21 - 2s - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 499/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 500/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 501/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 502/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 503/1000
# 21/21 - 2s - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 504/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 505/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 506/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 507/1000
# 21/21 - 2s - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 508/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 509/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 510/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 511/1000
# 21/21 - 2s - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 512/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 513/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 514/1000
# 21/21 - 2s - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 515/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 516/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 517/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 518/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 519/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 520/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 521/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 522/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 523/1000
# 21/21 - 2s - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 524/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 525/1000
# 21/21 - 2s - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 526/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 527/1000
# 21/21 - 2s - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 528/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 529/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 530/1000
# 21/21 - 2s - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 531/1000
# 21/21 - 2s - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 532/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 533/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 534/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 535/1000
# 21/21 - 2s - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 536/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 537/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 538/1000
# 21/21 - 2s - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 0.0000e+00
# Epoch 539/1000
# 21/21 - 2s - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 540/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 541/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 542/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 543/1000
# 21/21 - 2s - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 544/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 545/1000
# 21/21 - 2s - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 546/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 547/1000
# 21/21 - 2s - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 548/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 549/1000
# 21/21 - 2s - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 550/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 551/1000
# 21/21 - 2s - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 552/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 553/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 554/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 555/1000
# 21/21 - 2s - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 556/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 557/1000
# 21/21 - 2s - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 558/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 559/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 560/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 561/1000
# 21/21 - 2s - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 562/1000
# 21/21 - 2s - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 563/1000
# 21/21 - 2s - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 564/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 565/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 566/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 567/1000
# 21/21 - 2s - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0094 - val_accuracy: 0.0000e+00
# Epoch 568/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 569/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 570/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 571/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 572/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 573/1000
# 21/21 - 2s - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 574/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 575/1000
# 21/21 - 2s - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 576/1000
# 21/21 - 2s - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 577/1000
# 21/21 - 2s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 578/1000
# 21/21 - 2s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 579/1000
# 21/21 - 2s - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 580/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0058 - val_accuracy: 0.0000e+00
# Epoch 581/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 582/1000
# 21/21 - 2s - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 583/1000
# 21/21 - 2s - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 584/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 585/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 586/1000
# 21/21 - 2s - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 587/1000
# 21/21 - 2s - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0054 - val_accuracy: 0.0000e+00
# Epoch 588/1000
# 21/21 - 2s - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 589/1000
# 21/21 - 2s - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 590/1000
# 21/21 - 2s - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 591/1000
# 21/21 - 2s - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 592/1000
# 21/21 - 2s - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 593/1000
# 21/21 - 2s - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 594/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 595/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 596/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 597/1000
# 21/21 - 2s - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 598/1000
# 21/21 - 2s - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 599/1000
# 21/21 - 2s - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 600/1000
# 21/21 - 2s - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 601/1000
# 21/21 - 2s - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 602/1000
# 21/21 - 2s - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 603/1000
# 21/21 - 2s - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0057 - val_accuracy: 0.0000e+00
# Epoch 604/1000
# 21/21 - 2s - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 605/1000
# 21/21 - 2s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0000e+00
# Epoch 606/1000
# 21/21 - 2s - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 607/1000
# 21/21 - 2s - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 608/1000
# 21/21 - 2s - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 609/1000
# 21/21 - 2s - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 610/1000
